# %%
#!pip install beautifulsoup
#!wget https://dumps.wikimedia.org/enwiki/20190420/enwiki-20190420-pages-articles-multistream1.xml-p10p30302.bz2
#!bunzip2 enwiki-20190420-pages-articles-multistream1.xml-p10p30302.bz2

# %%
# Count lines, words, characters in XML data file
# !wc enwiki-20190420-pages-articles-multistream1.xml-p10p30302
# Out:
#  4586335 74563548 642819893 enwiki-20190420-pages-articles-multistream1.xml-p10p30302

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_pages_from_xml_file(filename, start_tag='<page>', end_tag='</page>'):
    """Yields each page from the specified XML data file."""
    page = None
    with open(filename) as f:
        for line in f:
            if start_tag in line:
                page = []
                page.append(line)
            elif end_tag in line:
                page.append(line)
                page_xml = ''.join(page)
                yield page_xml
                page = None
            else:
                if page is not None:
                    page.append(line)

# %%
filename = 'enwiki-20190420-pages-articles-multistream1.xml-p10p30302'
pages = list(get_pages_from_xml_file(filename))

# %%
def get_title_from_page_xml(page_xml):
    """Returns the title of the given page."""
    soup = BeautifulSoup(page_xml, 'lxml')
    return soup.select_one('title').text

# %%
len(pages)  # Show the number of pages
# Out:
# 19822

# %%
# %time titles = [get_title_from_page_xml(page) for page in pages]
# Out:
# CPU times: user 27.1 s, sys: 1.46 s, total: 28.6 s
# Wall time: 28.9 s

# %%
titles[:5] + ['...'] + titles[-5:]  # Show the first and last 5 titles
# Out:
# ['AccessibleComputing',
#  'Anarchism',
#  'AfghanistanHistory',
#  'AfghanistanGeography',
#  'AfghanistanPeople',
#  '...',
#  'The Lord of the Rings/One Ring',
#  'Tax Freedom Day',
#  'Tax',
#  'Transhumanism',
#  'TARDIS']

# %%
print(pages[0])  # Print the first page
# Out:
#   <page>
#     <title>AccessibleComputing</title>
#     <ns>0</ns>
#     <id>10</id>
#     <redirect title="Computer accessibility" />
#     <revision>
#       <id>854851586</id>
#       <parentid>834079434</parentid>
#       <timestamp>2018-08-14T06:47:24Z</timestamp>
#       <contributor>
#         <username>Godsy</username>
#         <id>23257138</id>
#       </contributor>
#       <comment>remove from category for seeking instructions on rcats</comment>
#       <model>wikitext</model>
#       <format>text/x-wiki</format>
#       <text xml:space="preserve">#REDIRECT [[Computer accessibility]]
#
# {{R from move}}
# {{R from CamelCase}}
# {{R unprintworthy}}</text>
#       <sha1>42l0cvblwtb4nnupxm6wo000d27t6kf</sha1>
#     </revision>
#   </page>

# %%
def get_text_from_page_xml(page):
    """Returns the text of the given page."""
    page_xml = ''.join(page)
    soup1 = BeautifulSoup(page_xml, 'lxml')
    return soup1.select_one('text').text

# %%
page = pages[1]
soup = BeautifulSoup(page, 'lxml')
text = get_text_from_page_xml(page)
text, type(text)
# Out:
# ('{{redirect2|Anarchist|Anarchists|the fictional character|Anarchist (comics)|other uses|Anarchists (disambiguation)}}\n{{pp-move-indef}}{{short description|Political philosophy that advocates self-governed societies}}\n{{use dmy dates|date=July 2018}}\n{{use British English|date=January 2014}}\n{{anarchism sidebar}}\n{{basic forms of government}}\n\'\'\'Anarchism\'\'\' is an [[anti-authoritarian]] [[political philosophy]]{{sfnm|1a1=McLaughlin|1y=2007|1p=59|2a1=Flint|2y=2009|2p=27}} that advocates [[Self-governance|self-governed]] societies based on voluntary, [[cooperative]] institutions and the rejection of [[Hierarchy|hierarchies]] those societies view as unjust. These institutions are often described as [[Stateless society|stateless societies]],{{sfnm|1a1=Craig|1y=2005|1p=14|2a1=Sheehan|2y=2003|2p=85}} although several authors have defined them more specifically as distinct institutions based on non-hierarchical or [[Free association (communism and anarchism)|free associations]].{{sfn|Suissa|2006|p=7}} Anarchism holds the [[Sovereign state|state]] to be undesirable, unnecessary and harmful.{{sfnm|1a1=Craig|1y=2005|1p=14|2a1=McLean|2a2=McMillan|2y=2003|2loc=Anarchism}}\n\nAnarchism is often considered a [[Far-left politics|far-left]]   ideology{{sfnm|1a1=Brooks|1y=1994|1p=xi|2a1=Kahn|2y=2000|3a1=Moynihan|3y=2007}} and much of its [[Anarchist economics|economics]] and [[Anarchist law|legal philosophy]] reflect [[Libertarian socialism|anti-authoritarian interpretations]] of [[Anarcho-communism|communism]], [[Collectivist anarchism|collectivism]], [[Anarcho-syndicalism|syndicalism]], [[Mutualism (economic theory)|mutualism]], or [[participatory economics]].{{sfn|Guerin|1970|p=35|loc=Critique of authoritarian socialism}} As anarchism does not offer a fixed body of doctrine from a single particular worldview,{{sfn|Marshall|1993|pp=14–17}} many [[History of anarchism|anarchist types and traditions]] exist and varieties of anarchy diverge widely.{{sfn|Sylvan|2007|p=262}} [[Anarchist schools of thought]] can differ fundamentally, supporting anything from extreme [[individualism]] to complete [[collectivism]].{{sfn|McLean|McMillan|2003|loc=Anarchism}} Strains of anarchism have often been divided into the categories of [[Social anarchism|social]] and [[individualist anarchism]], or similar dual classifications.{{sfnm|1a1=Ostergaard|1y=2009|1p=14|1loc=Anarchism|2a1=Kropotkin|2y=2002|2p=5|3a1=Fowler|3y=1972}}\n\n== Etymology, terminology and definition ==\n{{see also|Anarchist terminology}}\nThe etymological origin of anarchism derives from ancient Greek word \'\'anarkhia\'\'. \'\'Anarkhia\'\' meant "without a ruler" as it was composed by the prefix a  (i.e. "without") and the word \'\'arkhos\'\' (i.e. leader or ruler). The suffix [[-ism]] is used to denote the ideological current that favours anarchism.{{sfnm|1a1=Bates|1y=2017|1p=128|2a1=Long|2y=2013|2p=217}} The first known use of this word was in 1642.{{sfn|Definition of Anarchism by Merriam-Webster| 2019}} Various factions within the [[French Revolution]] labelled opponents as anarchists  although few shared many views of later anarchists. There would be many revolutionaries of the early 19th century who contributed to the anarchist doctrines of the next generation, such as [[William Godwin]] and [[Wilhelm Weitling]], but they did not use the word anarchist or anarchism in describing themselves or their beliefs.{{sfn|Joll|1964|pp=27–37}}\n\nThe first political philosopher to call himself an anarchist was [[Pierre-Joseph Proudhon]], marking the formal birth of anarchism in the mid-19th century. Since the 1890s and beginning in France,{{sfn|Nettlau|1996|p=162}} the term [[libertarianism]] has often been used as a synonym for anarchism{{sfn|Guerin|1970|loc=The Basic Ideas of Anarchism}} and its use as a synonym is still common outside the United States.{{sfnm|1a1=Ward|1y=2004|1p=62|2a1=Goodway|2y=2006|2p=4|3a1=Skirda|3y=2002|3p=183|4a1=Fernández|4y=2009|4p=9}} On the other hand, some  ...
#  str)

# %%
data = []
for page in pages:
    row = {
        'title': get_title_from_page_xml(page),
        'text': get_text_from_page_xml(page),
    }
    data.append(row)

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#                                                 text                 title
# 0  #REDIRECT [[Computer accessibility]]\n\n{{R fr...   AccessibleComputing
# 1  {{redirect2|Anarchist|Anarchists|the fictional...             Anarchism
# 2  #REDIRECT [[History of Afghanistan]]\n\n{{Redi...    AfghanistanHistory
# 3  #REDIRECT [[Geography of Afghanistan]]\n\n{{Re...  AfghanistanGeography
# 4  #REDIRECT [[Demographics of Afghanistan]]\n\n{...     AfghanistanPeople

# %% [markdown]
# ### Challenge

# %% [markdown]
# #### 1. Create a Pandas dataframe containing the title and text of each page.
#
# * Implement the `get_text_from_page_xml` function above.
# * Re-create the dataframe with the text field filled in.
#
# #### 2. Identify the five pages that have the _longest_ text.
#
# * Find the length of each page's `<text>...</text>` element and add it to your dataframe.
# * Sort the data frame by text length, descending.
# * What are the titles of the five longest articles?

# %%
df['text_length'] = df['text'].map(lambda x: len(x))
df.sort_values(by = ['text_length'], ascending=False)
# Out:
#                                                     text  \
# 10165  {{short description|Wikipedia list page}}\n{{s...
# 15129  {{about|the country}}\n{{pp-semi-indef}}\n{{pp...
# 15287  {{Redirect|Philippine|the town in the Netherla...
# 9299   {{Short description|Overview of relations}}{{U...
# 8838   {{short description|Aspect of history}}\n{{pp-...
# 3219   {{For2|the Republic of China|[[Taiwan]]|other ...
# 18770  {{About|the Malaysian state|the Caribbean isla...
# 8399   {{Redirect|German History|the academic journal...
# 254    {{redirect|Apple (company)|other companies of ...
# 15008  {{short description|Unincorporated territory o...
# 9254   {{about|the country}}\n{{redirect|Italia}}\n{{...
# 9327   {{pp|small=yes}}\n{{redirect|Persia}}\n{{about...
# 17610  {{redirect|Berlusconi|other uses|Berlusconi (d...
# 17571  {{other uses}}\n{{pp-move-indef}}\n{{pp-vandal...
# 16657  {{about|the country}}\n{{pp-semi-indef|small=y...
# 2554   {{short description|Species of  bear found acr...
# 14938  {{short description|Republic in Central Europe...
# 8812   {{short description|Aspects of national histor...
# 11352  {{pp-protected|small=yes}}\n{{about|the Europe...
# 16734  {{short description|Period of Imperial Rome fo...
# 12598  {{short description|American rock band}}\n{{go...
# 4300   {{short description|(de facto) federal republi...
# 9595   {{pp-semi-indef}}\n{{Use American English|date...
# 7644   {{Other uses|Greece (disambiguation)|Hellas (d...
# 15546  {{short description|264th Pope of the Catholic...
# 8854   {{Redirect-distinguish|Islamic Resistance Move...
# 12584  {{Redirect|Gandhi}}\n{{pp-move-indef}}\n{{pp-s...
# 5300   {{short description|Baseball team and Major Le...
# 6233   {{short description|Wikimedia list article abo...
# 11717  {{Use dmy dates|date=August 2012}}\n<!--\nIMPO...
# ...                                                  ...
# 16269                                 #REDIRECT [[Pope]]
# 18325                                 #redirect[[Sulla]]
# 14893                                 #REDIRECT [[Pole]]
# 14814                                 #REDIRECT [[Ötzi]]
# 12860                                 #REDIRECT [[meme]]
# 10508                                 #REDIRECT [[Rumi]]
# 2470                                  #REDIRECT [[Oder]]
# 11096                                 #REDIRECT [[Kite]]
# 14579                                 #REDIRECT [[Odin]]
# 14580                                 #REDIRECT [[Odin]]
# 14804                                 #REDIRECT [[OPEC]]
# 19018                                 #REDIRECT [[SCSI]]
# 19605                                 #REDIRECT [[Bede]]
# 13408                                  #REDIRECT [[Mod]]
# 7827                                   #REDIRECT [[Gas]]
# 9813                                   #REDIRECT [[IBM]]
# 5000                                   #REDIRECT [[MP3]]
# 5449                                   #REDIRECT [[DVD]]
# 7155                                   #REDIRECT [[Cat]]
# 5295                                   #REDIRECT [[Tao]]
# 11221                                  #REDIRECT[[Omri]]
# 10918                                  #redirect[[Kémo]]
# 7826                                   #REDIRECT [[Gas]]
# 17284                                  #REDIRECT [[RDX]]
# 2660                                   #REDIRECT [[Pub]]
# 18508                                  #REDIRECT [[Sed]]
# 8347                                    #REDIRECT [[GI]]
# 2320                                    #REDIRECT [[BC]]
# 11173                                   #REDIRECT [[Ka]]
# 2310                                    #REDIRECT [[BC]]
#
#                                                    title  text_length
# 10165      List of compositions by Johann Sebastian Bach       432964
# 15129                                           Pakistan       376957
# 15287                                        Philippines       357950
# 9299                          Foreign relations of India       317725
# 8838                                    History of India       316816
# 3219                                               China       315438
# 18770                                              Sabah       314901
# 8399                                  History of Germany       310832
# 254                                           Apple Inc.       309208
# 15008                                        Puerto Rico       302550
# 9254                                               Italy       299499
# 9327                                                Iran       298178
# 17610                                  Silvio Berlusconi       296849
# 17571                                          Socialism       296445
# 16657                                             Russia       289161
# 2554                                          Brown bear       285607
# 14938                                             Poland       283772
# 8812                                   History of France       282871
# 11352                                          Lithuania       281838
# 16734                                       Roman Empire       279439
# 12598                              Marilyn Manson (band)       278896
# 4300                       Confederate States of America       277465
# 9595                    Immigration to the United States       277319
# 7644                                              Greece       276619
# 15546                                  Pope John Paul II       274523
# 8854                                               Hamas       273977
# 12584                                     Mahatma Gandhi       273384
# 5300                                      Detroit Tigers       272540
# 6233                  List of contemporary ethnic groups       272492
# 11717                                  List of agnostics       272327
# ...                                                  ...          ...
# 16269                                             Papacy           18
# 18325                             Lucius Cornelius Sulla           18
# 14893                                              PoleS           18
# 14814                                              Oetzi           18
# 12860                                      Memetic drift           18
# 10508                                  Jalal ad-Din Rumi           18
# 2470                                     Baltic Sea/Odra           18
# 11096                                       Kite history           18
# 14579                                   Odin's Nicknames           18
# 14580                                   Odin s Nicknames           18
# 14804  Organisation of the Petroleum Exporting Countries           18
# 19018                   Small Computer Systems Interface           18
# 19605                                 The Venerable Bede           18
# 13408                                               Mods           17
# 7827                                       Gaseous phase           17
# 9813         International Business Machines Corporation           17
# 5000                                Data compression/MP3           17
# 5449                                  Digital video disc           17
# 7155                              Felis catus Domesticus           17
# 5295                                                 Dao           17
# 11221                                          King Omri           17
# 10918                                     Kemo-Gribingui           17
# 7826                                       Gaseous state           17
# 17284                                             RDXold           17
# 2660                               British public houses           17
# 18508                           Sed programming language           17
# 8347                                                G.I.           16
# 2320                                                 B.C           16
# 11173                                                 KA           16
# 2310                                                B.C.           16
#
# [19822 rows x 3 columns]
